# %% [markdown]
# ### Import Libraries

# %%
# %%capture
# !pip install -U lightautoml

# %%
# Standard python libraries
import os
import time

# Essential DS libraries
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import torch

# LightAutoML presets, task and report generation
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task
from lightautoml.report.report_deco import ReportDeco

# Imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.pipeline import Pipeline
from scipy.stats import rankdata
import gc


from autowoe import AutoWoE
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ### Constants

# %%
N_THREADS = 10
N_FOLDS = 10
RANDOM_STATE = 42
TEST_SIZE = 0.3
TIMEOUT = 8*3600
TARGET_NAME = 'song_popularity'

TRAIN_PATH = '../input/song-popularity-prediction/train.csv'
TEST_PATH = '../input/song-popularity-prediction/testcsv'
SAMPLE_PATH = '../input/song-popularity-prediction/sample_submission.csv'

np.random.seed(RANDOM_STATE)
torch.set_num_threads(N_THREADS)

# %% [markdown]
# ### Load Data

# %%
# %%time

train_data = pd.read_csv('../input/song-popularity-prediction/train.csv')
test_data = pd.read_csv('../input/song-popularity-prediction/test.csv')
samp_sub = pd.read_csv('../input/song-popularity-prediction/sample_submission.csv')
# Out:
# CPU times: user 120 ms, sys: 25.1 ms, total: 145 ms
# Wall time: 293 ms

# %% [markdown]
# ### Scaling and Imputation

# %%
# %%time

iti = IterativeImputer()
Robust_scaler = RobustScaler()

target = ['song_popularity']
not_features = ['id', 'song_popularity']

cols = list(train_data.columns)
features = [feat for feat in cols if feat not in not_features]

train_knnimp = iti.fit_transform(train_data[features])
test_knnimp = iti.transform(test_data[features])

train_knnimp = Robust_scaler.fit_transform(train_knnimp)
test_knnimp = Robust_scaler.transform(test_knnimp)

train = pd.DataFrame(columns=train_data[features].columns, data=train_knnimp)
test = pd.DataFrame(columns=test_data[features].columns, data=test_knnimp)

train['song_popularity'] = train_data.song_popularity
train.insert(0, 'id', train_data.id)
test.insert(0, 'id', test_data.id)
# Out:
# CPU times: user 2.51 s, sys: 1.79 s, total: 4.3 s
# Wall time: 2.19 s

# %%
train_data = train.copy()
test_data = test.copy()
del train
del test
del train_knnimp
del test_knnimp
gc.collect()
# Out:
# 81

# %% [markdown]
# ### Train Test Split

# %%
# %%time
tr_data, te_data = train_test_split(train_data, 
                                    test_size=TEST_SIZE, 
                                    stratify=train_data[TARGET_NAME], 
                                    random_state=RANDOM_STATE)
print('Data splitted. Parts sizes: tr_data = {}, te_data = {}'.format(tr_data.shape, te_data.shape))
# Out:
# Data splitted. Parts sizes: tr_data = (28000, 15), te_data = (12000, 15)
# CPU times: user 19.6 ms, sys: 0 ns, total: 19.6 ms
# Wall time: 21.3 ms

# %% [markdown]
# ### Adding oofs and test-predictions from AutoWoe Models

# %%
def get_oof_and_test_pred(tr, te, real_te):
    skf = StratifiedKFold(n_splits=N_FOLDS)

    oof_preds_woe = np.zeros(len(tr))
    test_preds_woe = np.zeros(len(te))
    real_test_preds_woe = np.zeros(len(real_te))

    y = tr['song_popularity'].values

    for fold, (train_idx, val_idx) in enumerate(skf.split(y, y)):

        X_tr, X_val = tr.iloc[train_idx, :], tr.iloc[val_idx, :]

        auto_woe = AutoWoE(monotonic=False,
                         vif_th=20.,
                         imp_th=0,
                         th_const=32,
                         force_single_split=True,
                         min_bin_size = 0.005,
                         oof_woe=True,
                         n_folds=5,
                         n_jobs=N_THREADS,
                         regularized_refit=True,
                         verbose=0)

        auto_woe.fit(X_tr.sample(20000, random_state = 42).drop('id', axis = 1), 
                     target_name="song_popularity")

        val_pred = auto_woe.predict_proba(X_val)
        print("FOLD {}, AUC_SCORE = {:.5f}".format(fold, roc_auc_score(X_val['song_popularity'], val_pred)))

        oof_preds_woe[val_idx] = val_pred
        test_preds_woe += auto_woe.predict_proba(te) / N_FOLDS
        real_test_preds_woe += auto_woe.predict_proba(real_te) / N_FOLDS

    print("AUC_SCORE TRAIN = {:.5f}".format(roc_auc_score(tr_data['song_popularity'], oof_preds_woe)))
    print("AUC_SCORE TEST = {:.5f}".format(roc_auc_score(te_data['song_popularity'], test_preds_woe)))
    
    return oof_preds_woe, test_preds_woe, real_test_preds_woe

# %%
oof_preds_woe, test_preds_woe, real_test_preds_woe = get_oof_and_test_pred(tr_data, te_data, test_data)

tr_data['missed_cnt'] = tr_data.isna().sum(axis=1)
te_data['missed_cnt'] = te_data.isna().sum(axis=1)
test_data['missed_cnt'] = test_data.isna().sum(axis=1)
oof_preds_woe2, test_preds_woe2, real_test_preds_woe2 = get_oof_and_test_pred(tr_data, te_data, test_data)

print("AUC_SCORE TEST = {:.5f}".format(roc_auc_score(te_data['song_popularity'], test_preds_woe)))
print("AUC_SCORE TEST = {:.5f}".format(roc_auc_score(te_data['song_popularity'], test_preds_woe2)))
print("AUC_SCORE TEST = {:.5f}".format(roc_auc_score(te_data['song_popularity'], 0.5 * test_preds_woe + 0.5 * test_preds_woe2)))
print("AUC_SCORE TEST = {:.5f}".format(roc_auc_score(te_data['song_popularity'], 0.5 * rankdata(test_preds_woe) + 0.5 * rankdata(test_preds_woe2))))

tr_data['oof_woe_1'] = oof_preds_woe
te_data['oof_woe_1'] = test_preds_woe
test_data['oof_woe_1'] = real_test_preds_woe

tr_data['oof_woe_2'] = oof_preds_woe2
te_data['oof_woe_2'] = test_preds_woe2
test_data['oof_woe_2'] = real_test_preds_woe2

tr_data['oof_woe_12'] = 0.5 * oof_preds_woe + 0.5 * oof_preds_woe2
te_data['oof_woe_12'] = 0.5 * test_preds_woe + 0.5 * test_preds_woe2
test_data['oof_woe_12'] = 0.5 * real_test_preds_woe + 0.5 * real_test_preds_woe2

tr_data['rank_oof_woe_1'] = rankdata(oof_preds_woe)
te_data['rank_oof_woe_1'] = rankdata(test_preds_woe)
test_data['rank_oof_woe_1'] = rankdata(real_test_preds_woe)

tr_data['rank_oof_woe_2'] = rankdata(oof_preds_woe2)
te_data['rank_oof_woe_2'] = rankdata(test_preds_woe2)
test_data['rank_oof_woe_2'] = rankdata(real_test_preds_woe2)

tr_data['rank_oof_woe_12'] = 0.5 * rankdata(oof_preds_woe) + 0.5 * rankdata(oof_preds_woe2)
te_data['rank_oof_woe_12'] = 0.5 * rankdata(test_preds_woe) + 0.5 * rankdata(test_preds_woe2)
test_data['rank_oof_woe_12'] = 0.5 * rankdata(real_test_preds_woe) + 0.5 * rankdata(real_test_preds_woe2)
# Out:
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5845, number of negative: 10155
# [LightGBM] [Info] Total Bins 2805
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.365312 -> initscore=-0.552380
# [LightGBM] [Info] Start training from score -0.552380
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	val_set's auc: 0.560498
#  features [] have low importance
# Feature audio_mode removed due to single WOE value
# Feature time_signature removed due to low AUC value 0.5042955491763604
# C parameter range in [0.0003718854592785422:3.718854592785422], 20 values
# Result(score=0.5757247731809313, reg_alpha=0.20288563708324708, is_neg=True, min_weights=energy             -0.655271
# tempo              -0.624868
# audio_valence      -0.725617
# acousticness       -0.587174
# liveness           -0.741699
# danceability       -0.703460
# song_duration_ms   -0.654421
# instrumentalness   -0.861344
# loudness            0.000000
# speechiness        -0.948029
# key                -0.711100
# dtype: float64)
# FOLD 0, AUC_SCORE = 0.56885
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5857, number of negative: 10143
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366063 -> initscore=-0.549146
# [LightGBM] [Info] Start training from score -0.549146
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [29]	val_set's auc: 0.57819
#  features [] have low importance
# Feature audio_mode removed due to single WOE value
# Feature time_signature removed due to low AUC value 0.4995512411430456
# C parameter range in [0.0003727171077152441:3.727171077152441], 20 values
# Result(score=0.5750822656548776, reg_alpha=0.1252261754112479, is_neg=True, min_weights=energy             -0.668451
# audio_valence      -0.647933
# tempo              -0.569095
# liveness           -0.715745
# instrumentalness   -0.944802
# danceability       -0.659781
# acousticness       -0.571065
# song_duration_ms   -0.743182
# speechiness        -0.853173
# loudness            0.000000
# key                -0.358867
# dtype: float64)
# FOLD 1, AUC_SCORE = 0.58226
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5861, number of negative: 10139
# [LightGBM] [Info] Total Bins 2805
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366312 -> initscore=-0.548069
# [LightGBM] [Info] Start training from score -0.548069
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	val_set's auc: 0.573949
#  features [] have low importance
# Feature audio_mode removed due to single WOE value
# Feature time_signature removed due to low AUC value 0.5036592390623569
# C parameter range in [0.0003734129947722181:3.734129947722181], 20 values
# Result(score=0.5773932582477664, reg_alpha=0.8721887487267072, is_neg=True, min_weights=energy             -0.619739
# audio_valence      -0.648291
# tempo              -0.619412
# liveness           -0.744893
# loudness           -0.221196
# song_duration_ms   -0.816129
# danceability       -0.711661
# acousticness       -0.578244
# instrumentalness   -1.001691
# key                -0.879683
# speechiness        -1.180358
# dtype: float64)
# FOLD 2, AUC_SCORE = 0.54900
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5876, number of negative: 10124
# [LightGBM] [Info] Total Bins 2803
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367250 -> initscore=-0.544033
# [LightGBM] [Info] Start training from score -0.544033
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	val_set's auc: 0.566513
#  features [] have low importance
# Feature audio_mode removed due to single WOE value
# Feature time_signature removed due to low AUC value 0.5044204644840011
# C parameter range in [0.0003746721618583739:3.7467216185837393], 20 values
# Result(score=0.5752424981346607, reg_alpha=0.20440594908836696, is_neg=True, min_weights=energy             -0.641397
# audio_valence      -0.686517
# tempo              -0.582366
# liveness           -0.689685
# acousticness       -0.411490
# song_duration_ms   -0.682963
# danceability       -0.659501
# instrumentalness   -0.872534
# loudness            0.000000
# speechiness        -0.815055
# key                -0.614438
# dtype: float64)
# FOLD 3, AUC_SCORE = 0.56017
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5878, number of negative: 10122
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367375 -> initscore=-0.543495
# [LightGBM] [Info] Start training from score -0.543495
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [6]	val_set's auc: 0.561821
#  features ['audio_mode', 'time_signature'] have low importance
# C parameter range in [0.00037313432835820896:3.7313432835820897], 20 values
# Result(score=0.5749355725638241, reg_alpha=0.12536635396581272, is_neg=True, min_weights=energy             -0.702794
# tempo              -0.624683
# audio_valence      -0.561379
# liveness           -0.717967
# loudness            0.000000
# song_duration_ms   -0.537304
# acousticness       -0.449857
# danceability       -0.703665
# instrumentalness   -0.821059
# speechiness        -0.741108
# key                -0.245934
# dtype: float64)
# FOLD 4, AUC_SCORE = 0.54461
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5884, number of negative: 10116
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367750 -> initscore=-0.541882
# [LightGBM] [Info] Start training from score -0.541882
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [57]	val_set's auc: 0.57196
#  features [] have low importance
# Feature audio_mode removed due to low AUC value 0.5004802482498101
# C parameter range in [0.00037064492216456633:3.7064492216456633], 20 values
# Result(score=0.5761897434732924, reg_alpha=0.12452995872067386, is_neg=True, min_weights=energy             -0.664763
# tempo              -0.562094
# audio_valence      -0.571405
# liveness           -0.683578
# instrumentalness   -0.888796
# acousticness       -0.508892
# loudness            0.000000
# danceability       -0.554101
# song_duration_ms   -0.439000
# speechiness        -0.709731
# key                -0.402118
# time_signature      0.000000
# dtype: float64)
# FOLD 5, AUC_SCORE = 0.55293
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5880, number of negative: 10120
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367500 -> initscore=-0.542957
# [LightGBM] [Info] Start training from score -0.542957
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [28]	val_set's auc: 0.57107
#  features [] have low importance
# Feature audio_mode removed due to low AUC value 0.5000493862786467
# Feature time_signature removed due to low AUC value 0.5030668749558415
# C parameter range in [0.0003695491500369549:3.695491500369549], 20 values
# Result(score=0.5703323435420597, reg_alpha=0.12416179919747897, is_neg=True, min_weights=energy             -0.642643
# tempo              -0.532500
# audio_valence      -0.716508
# liveness           -0.692309
# danceability       -0.704043
# acousticness       -0.404382
# instrumentalness   -0.922415
# loudness            0.000000
# speechiness        -0.672124
# song_duration_ms   -0.144615
# key                -0.186397
# dtype: float64)
# FOLD 6, AUC_SCORE = 0.56339
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5867, number of negative: 10133
# [LightGBM] [Info] Total Bins 2805
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366687 -> initscore=-0.546454
# [LightGBM] [Info] Start training from score -0.546454
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [3]	val_set's auc: 0.570125
#  features ['time_signature'] have low importance
# Feature audio_mode removed due to low AUC value 0.499564458307172
# C parameter range in [0.0003669724770642202:3.669724770642202], 20 values
# Result(score=0.574257320127735, reg_alpha=0.5278715186376746, is_neg=True, min_weights=energy             -0.727993
# tempo              -0.705743
# audio_valence      -0.725414
# liveness           -0.849144
# loudness           -0.181896
# danceability       -0.644145
# song_duration_ms   -0.615152
# instrumentalness   -0.913321
# speechiness        -1.051922
# acousticness       -0.162175
# key                -0.548441
# dtype: float64)
# FOLD 7, AUC_SCORE = 0.55983
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5862, number of negative: 10138
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366375 -> initscore=-0.547800
# [LightGBM] [Info] Start training from score -0.547800
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	val_set's auc: 0.581919
#  features [] have low importance
# Feature audio_mode removed due to low AUC value 0.5004898530085731
# C parameter range in [0.0003679175864606328:3.679175864606328], 20 values
# Result(score=0.5778334883540782, reg_alpha=0.12361362348358282, is_neg=True, min_weights=energy             -0.665803
# tempo              -0.520056
# audio_valence      -0.662733
# liveness           -0.669919
# loudness            0.000000
# danceability       -0.676872
# instrumentalness   -0.847717
# acousticness       -0.517898
# speechiness        -0.773398
# song_duration_ms   -0.560239
# key                -0.453024
# time_signature      0.000000
# dtype: float64)
# FOLD 8, AUC_SCORE = 0.57001
#  features [] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5885, number of negative: 10115
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367812 -> initscore=-0.541613
# [LightGBM] [Info] Start training from score -0.541613
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [27]	val_set's auc: 0.5821
#  features [] have low importance
# Feature audio_mode removed due to low AUC value 0.4989476923404713
# C parameter range in [0.0003711952487008166:3.711952487008166], 20 values
# Result(score=0.5761176799845916, reg_alpha=0.12471485843666595, is_neg=True, min_weights=energy             -0.672884
# tempo              -0.516505
# audio_valence      -0.584425
# liveness           -0.683729
# loudness            0.000000
# instrumentalness   -0.825333
# danceability       -0.583691
# speechiness        -0.746482
# acousticness       -0.416836
# song_duration_ms   -0.125974
# key                -0.204210
# time_signature      0.000000
# dtype: float64)
# FOLD 9, AUC_SCORE = 0.54298
# AUC_SCORE TRAIN = 0.55933
# AUC_SCORE TEST = 0.56475
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5845, number of negative: 10155
# [LightGBM] [Info] Total Bins 2805
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.365312 -> initscore=-0.552380
# [LightGBM] [Info] Start training from score -0.552380
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	val_set's auc: 0.560498
#  features [] have low importance
# Feature audio_mode removed due to single WOE value
# Feature time_signature removed due to low AUC value 0.5042955491763604
# C parameter range in [0.0003718854592785422:3.718854592785422], 20 values
# Result(score=0.5757247731809313, reg_alpha=0.20288563708324708, is_neg=True, min_weights=energy             -0.655271
# tempo              -0.624868
# audio_valence      -0.725617
# acousticness       -0.587174
# liveness           -0.741699
# danceability       -0.703460
# song_duration_ms   -0.654421
# instrumentalness   -0.861344
# loudness            0.000000
# speechiness        -0.948029
# key                -0.711100
# dtype: float64)
# FOLD 0, AUC_SCORE = 0.56885
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5857, number of negative: 10143
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366063 -> initscore=-0.549146
# [LightGBM] [Info] Start training from score -0.549146
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [29]	val_set's auc: 0.57819
#  features [] have low importance
# Feature audio_mode removed due to single WOE value
# Feature time_signature removed due to low AUC value 0.4995512411430456
# C parameter range in [0.0003727171077152441:3.727171077152441], 20 values
# Result(score=0.5750822656548776, reg_alpha=0.1252261754112479, is_neg=True, min_weights=energy             -0.668451
# audio_valence      -0.647933
# tempo              -0.569095
# liveness           -0.715745
# instrumentalness   -0.944802
# danceability       -0.659781
# acousticness       -0.571065
# song_duration_ms   -0.743182
# speechiness        -0.853173
# loudness            0.000000
# key                -0.358867
# dtype: float64)
# FOLD 1, AUC_SCORE = 0.58226
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5861, number of negative: 10139
# [LightGBM] [Info] Total Bins 2805
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366312 -> initscore=-0.548069
# [LightGBM] [Info] Start training from score -0.548069
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	val_set's auc: 0.573949
#  features [] have low importance
# Feature audio_mode removed due to single WOE value
# Feature time_signature removed due to low AUC value 0.5036592390623569
# C parameter range in [0.0003734129947722181:3.734129947722181], 20 values
# Result(score=0.5773932582477664, reg_alpha=0.8721887487267072, is_neg=True, min_weights=energy             -0.619739
# audio_valence      -0.648291
# tempo              -0.619412
# liveness           -0.744893
# loudness           -0.221196
# song_duration_ms   -0.816129
# danceability       -0.711661
# acousticness       -0.578244
# instrumentalness   -1.001691
# key                -0.879683
# speechiness        -1.180358
# dtype: float64)
# FOLD 2, AUC_SCORE = 0.54900
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5876, number of negative: 10124
# [LightGBM] [Info] Total Bins 2803
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367250 -> initscore=-0.544033
# [LightGBM] [Info] Start training from score -0.544033
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	val_set's auc: 0.566513
#  features [] have low importance
# Feature audio_mode removed due to single WOE value
# Feature time_signature removed due to low AUC value 0.5044204644840011
# C parameter range in [0.0003746721618583739:3.7467216185837393], 20 values
# Result(score=0.5752424981346607, reg_alpha=0.20440594908836696, is_neg=True, min_weights=energy             -0.641397
# audio_valence      -0.686517
# tempo              -0.582366
# liveness           -0.689685
# acousticness       -0.411490
# song_duration_ms   -0.682963
# danceability       -0.659501
# instrumentalness   -0.872534
# loudness            0.000000
# speechiness        -0.815055
# key                -0.614438
# dtype: float64)
# FOLD 3, AUC_SCORE = 0.56017
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5878, number of negative: 10122
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367375 -> initscore=-0.543495
# [LightGBM] [Info] Start training from score -0.543495
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [6]	val_set's auc: 0.561821
#  features ['audio_mode', 'time_signature'] have low importance
# C parameter range in [0.00037313432835820896:3.7313432835820897], 20 values
# Result(score=0.5749355725638241, reg_alpha=0.12536635396581272, is_neg=True, min_weights=energy             -0.702794
# tempo              -0.624683
# audio_valence      -0.561379
# liveness           -0.717967
# loudness            0.000000
# song_duration_ms   -0.537304
# acousticness       -0.449857
# danceability       -0.703665
# instrumentalness   -0.821059
# speechiness        -0.741108
# key                -0.245934
# dtype: float64)
# FOLD 4, AUC_SCORE = 0.54461
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5884, number of negative: 10116
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367750 -> initscore=-0.541882
# [LightGBM] [Info] Start training from score -0.541882
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [57]	val_set's auc: 0.57196
#  features [] have low importance
# Feature audio_mode removed due to low AUC value 0.5004802482498101
# C parameter range in [0.00037064492216456633:3.7064492216456633], 20 values
# Result(score=0.5761897434732924, reg_alpha=0.12452995872067386, is_neg=True, min_weights=energy             -0.664763
# tempo              -0.562094
# audio_valence      -0.571405
# liveness           -0.683578
# instrumentalness   -0.888796
# acousticness       -0.508892
# loudness            0.000000
# danceability       -0.554101
# song_duration_ms   -0.439000
# speechiness        -0.709731
# key                -0.402118
# time_signature      0.000000
# dtype: float64)
# FOLD 5, AUC_SCORE = 0.55293
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5880, number of negative: 10120
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367500 -> initscore=-0.542957
# [LightGBM] [Info] Start training from score -0.542957
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [28]	val_set's auc: 0.57107
#  features [] have low importance
# Feature audio_mode removed due to low AUC value 0.5000493862786467
# Feature time_signature removed due to low AUC value 0.5030668749558415
# C parameter range in [0.0003695491500369549:3.695491500369549], 20 values
# Result(score=0.5703323435420597, reg_alpha=0.12416179919747897, is_neg=True, min_weights=energy             -0.642643
# tempo              -0.532500
# audio_valence      -0.716508
# liveness           -0.692309
# danceability       -0.704043
# acousticness       -0.404382
# instrumentalness   -0.922415
# loudness            0.000000
# speechiness        -0.672124
# song_duration_ms   -0.144615
# key                -0.186397
# dtype: float64)
# FOLD 6, AUC_SCORE = 0.56339
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5867, number of negative: 10133
# [LightGBM] [Info] Total Bins 2805
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366687 -> initscore=-0.546454
# [LightGBM] [Info] Start training from score -0.546454
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [3]	val_set's auc: 0.570125
#  features ['time_signature'] have low importance
# Feature audio_mode removed due to low AUC value 0.499564458307172
# C parameter range in [0.0003669724770642202:3.669724770642202], 20 values
# Result(score=0.574257320127735, reg_alpha=0.5278715186376746, is_neg=True, min_weights=energy             -0.727993
# tempo              -0.705743
# audio_valence      -0.725414
# liveness           -0.849144
# loudness           -0.181896
# danceability       -0.644145
# song_duration_ms   -0.615152
# instrumentalness   -0.913321
# speechiness        -1.051922
# acousticness       -0.162175
# key                -0.548441
# dtype: float64)
# FOLD 7, AUC_SCORE = 0.55983
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5862, number of negative: 10138
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.366375 -> initscore=-0.547800
# [LightGBM] [Info] Start training from score -0.547800
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	val_set's auc: 0.581919
#  features [] have low importance
# Feature audio_mode removed due to low AUC value 0.5004898530085731
# C parameter range in [0.0003679175864606328:3.679175864606328], 20 values
# Result(score=0.5778334883540782, reg_alpha=0.12361362348358282, is_neg=True, min_weights=energy             -0.665803
# tempo              -0.520056
# audio_valence      -0.662733
# liveness           -0.669919
# loudness            0.000000
# danceability       -0.676872
# instrumentalness   -0.847717
# acousticness       -0.517898
# speechiness        -0.773398
# song_duration_ms   -0.560239
# key                -0.453024
# time_signature      0.000000
# dtype: float64)
# FOLD 8, AUC_SCORE = 0.57001
#  features ['missed_cnt'] contain too many nans or identical values
# [LightGBM] [Warning] Starting from the 2.1.2 version, default value for the "boost_from_average" parameter in "binary" objective is true.
# This may cause significantly different results comparing to the previous versions of LightGBM.
# Try to set boost_from_average=false, if your old models produce bad results
# [LightGBM] [Info] Number of positive: 5885, number of negative: 10115
# [LightGBM] [Info] Total Bins 2804
# [LightGBM] [Info] Number of data: 16000, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.367812 -> initscore=-0.541613
# [LightGBM] [Info] Start training from score -0.541613
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [27]	val_set's auc: 0.5821
#  features [] have low importance
# Feature audio_mode removed due to low AUC value 0.4989476923404713
# C parameter range in [0.0003711952487008166:3.711952487008166], 20 values
# Result(score=0.5761176799845916, reg_alpha=0.12471485843666595, is_neg=True, min_weights=energy             -0.672884
# tempo              -0.516505
# audio_valence      -0.584425
# liveness           -0.683729
# loudness            0.000000
# instrumentalness   -0.825333
# danceability       -0.583691
# speechiness        -0.746482
# acousticness       -0.416836
# song_duration_ms   -0.125974
# key                -0.204210
# time_signature      0.000000
# dtype: float64)
# FOLD 9, AUC_SCORE = 0.54298
# AUC_SCORE TRAIN = 0.55933
# AUC_SCORE TEST = 0.56475
# AUC_SCORE TEST = 0.56475
# AUC_SCORE TEST = 0.56475
# AUC_SCORE TEST = 0.56475
# AUC_SCORE TEST = 0.56475

# %% [markdown]
# ### Model Building

# %%
# %%time

task = Task('binary', )
roles = {'target': TARGET_NAME,
         'drop': ['id']}
# Out:
# CPU times: user 5.62 ms, sys: 63 µs, total: 5.68 ms
# Wall time: 4.6 ms

# %%
# %%time 

automl = TabularAutoML(task = task, 
                        timeout = TIMEOUT,
                        cpu_limit = N_THREADS,
                        reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
                        general_params = {'use_algos': [['lgb', 'lgb_tuned', 'linear_l2', 'cb', 'cb_tuned', 'lgb_tuned', 'lgb_tuned', 'lgb_tuned', 'lgb', 'lgb_tuned', 'linear_l2'], ['linear_l2']]},
                        selection_params = {'mode': 0})

RD = ReportDeco(output_path = 'tabularAutoML_model_report')
automl_rd = RD(automl)
oof_pred = automl_rd.fit_predict(tr_data, roles = roles)
te_pred = automl_rd.predict(te_data)
print('Prediction for te_data:\n{}\nShape = {}'.format(te_pred, te_pred.shape))
print('OOF score: {}'.format(roc_auc_score(tr_data[TARGET_NAME].values, oof_pred.data[:, 0])))
print('HOLDOUT score: {}'.format(roc_auc_score(te_data[TARGET_NAME].values, te_pred.data[:, 0])))
# Out:
# Prediction for te_data:
# array([[0.34075361],
#        [0.35829973],
#        [0.3035342 ],
#        ...,
#        [0.3489387 ],
#        [0.38342965],
#        [0.32817546]], dtype=float32)
# Shape = (12000, 1)
# OOF score: 0.5684230836610502
# HOLDOUT score: 0.5776435707738623
# CPU times: user 18min 17s, sys: 3min 42s, total: 21min 59s
# Wall time: 13min 11s

# %% [markdown]
# ### Training on Whole Data

# %%
train_data = pd.concat([tr_data, te_data]).reset_index(drop = True)
print(train_data.shape)
train_data.head()
# Out:
# (40000, 22)
#       id  song_duration_ms  acousticness  danceability    energy  \
# 0  13898         -0.947208      0.324330      0.524932 -0.336972
# 1  37144         -1.305897     -0.323108      0.602268  0.918888
# 2    980          0.368399      0.414091     -0.152927  0.174795
# 3   1816         -0.287670      0.598472      0.292502  0.811662
# 4  27531         -0.428607     -0.340319     -1.288730  0.355879
#
#    instrumentalness       key  liveness  loudness  audio_mode  ...  \
# 0          0.367463  0.790971 -0.643172 -0.165804         0.0  ...
# 1         -0.823720  0.624304  1.273297  0.301763         0.0  ...
# 2          0.666655  0.790971 -0.184816 -1.136889         0.0  ...
# 3         -0.792982  0.457637 -0.343100  0.471242         0.0  ...
# 4          0.416870 -0.709029  0.514374  0.126536         0.0  ...
#
#    time_signature  audio_valence  song_popularity  missed_cnt  oof_woe_1  \
# 0             1.0       0.656491                0           0   0.325070
# 1             0.0       0.491159                0           0   0.316570
# 2             0.0      -0.880087                1           0   0.354439
# 3             0.0       0.645036                1           0   0.414546
# 4             1.0      -0.274986                0           0   0.310920
#
#    oof_woe_2  oof_woe_12  rank_oof_woe_1  rank_oof_woe_2  rank_oof_woe_12
# 0   0.325070    0.325070          6964.0          6964.0           6964.0
# 1   0.316570    0.316570          5704.0          5704.0           5704.0
# 2   0.354439    0.354439         12151.0         12151.0          12151.0
# 3   0.414546    0.414546         22683.0         22683.0          22683.0
# 4   0.310920    0.310920          4914.0          4914.0           4914.0
#
# [5 rows x 22 columns]

# %%
# %%time 
automl = TabularUtilizedAutoML(task = task, 
                       timeout = TIMEOUT,
                       cpu_limit = N_THREADS,
                       reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
                       tuning_params = {'max_tuning_time': 3600}, # more time for params tuning
                       general_params = {'use_algos': [['lgb', 'lgb_tuned', 'linear_l2', 'cb', 'cb_tuned', 'lgb_tuned', 'lgb_tuned', 'lgb_tuned', 'lgb', 'lgb_tuned', 'linear_l2'], ['linear_l2']]},
                       selection_params = {'mode': 0})

oof_pred = automl.fit_predict(train_data, roles = roles)
# Out:
# CPU times: user 14h 7min 59s, sys: 26min 49s, total: 14h 34min 48s
# Wall time: 7h 45min 30s

# %%
print('OOF score: {}'.format(roc_auc_score(train_data[TARGET_NAME].values, oof_pred.data[:, 0])))
# Out:
# OOF score: 0.5786278843633059

# %% [markdown]
# ### Create Submission

# %%
test_pred = automl.predict(test_data)
samp_sub[TARGET_NAME] = test_pred.data[:, 0]
samp_sub.to_csv('./LightAUTOMLsubmission_TUNED.csv', index = False)
print('Prediction for test_data:\n{}\nShape = {}'.format(test_pred, test_pred.shape))
# Out:
# Prediction for test_data:
# array([[0.39818868],
#        [0.50590307],
#        [0.30382237],
#        ...,
#        [0.3438912 ],
#        [0.436447  ],
#        [0.2849599 ]], dtype=float32)
# Shape = (10000, 1)
